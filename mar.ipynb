# %%
import requests
import pandas as pd

# %%
df_maridajes = pd.read_excel("Maridajes por región.xlsx")

df_maridajes

df_maridajes=df_maridajes.drop(0)

# %%
df_maridajes
# Out:
#                            Table 1  \
# 1                           Región
# 2             Comunidad Valenciana
# 3               Castilla-La Mancha
# 4                 Variado (España)
# 5                           Aragón
# 6                          Navarra
# 7                         Cataluña
# 8                 Región de Murcia
# 9                         La Rioja
# 10                 Castilla y León
# 11                         Galicia
# 12                       Andalucía
# 13                     Extremadura
# 14        Región Lisboa (Portugal)
# 15      Región Alentejo (Portugal)
# 16         Región Norte (Portugal)
# 17        Región Centro (Portugal)
# 18              Variado (Portugal)
# 19       Región Algarve (Portugal)
# 20                Sicilia (Italia)
# 21                Abruzos (Italia)
# 22                 Apulia (Italia)
# 23               Burdeos (Francia)
# 24                         Francia
# 25  Languedoc-Roussillon (Francia)
# ...

# %%
df_maridajes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 1 to 39
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Table 1     39 non-null     object
#  1   Unnamed: 1  39 non-null     object
#  2   Unnamed: 2  39 non-null     object
#  3   Unnamed: 3  39 non-null     object
#  4   Unnamed: 4  39 non-null     object
#  5   Unnamed: 5  39 non-null     object
# dtypes: object(6)
# memory usage: 2.0+ KB

# %%
df_maridajes.shape
print(f"El número de filas que tenemos es {df_maridajes.shape[0]}, y el número de columnas es {df_maridajes.shape[1]}")
# Out:
# El número de filas que tenemos es 39, y el número de columnas es 6

# %%
nuevos_nombres = {"Table 1":'Region' , 'Unnamed: 1': 'Vino Blanco' , "Unnamed: 2": "Vino Tinto" , "Unnamed: 3": "Vino Rosado" , "Unnamed: 4": "Vino Espumoso" ,  "Unnamed: 5": "Vino Dulce"  }
maridajes = df_maridajes.rename(columns=nuevos_nombres)

# %%
nuevos_nombres
# Out:
# {'Table 1': 'Region',
#  'Unnamed: 1': 'Vino Blanco',
#  'Unnamed: 2': 'Vino Tinto',
#  'Unnamed: 3': 'Vino Rosado',
#  'Unnamed: 4': 'Vino Espumoso',
#  'Unnamed: 5': 'Vino Dulce'}

# %%
maridajes=maridajes.drop(maridajes.index[0])

# %%
maridajes.head()
# Out:
#                  Region                                      Vino Blanco  \
# 2  Comunidad Valenciana        Arroz a banda, Fideuá, Ensalada de tomate
# 3    Castilla-La Mancha                           Pisto manchego, Gachas
# 4      Variado (España)         Pulpo a la gallega, Ensalada de mariscos
# 5                Aragón              Ternasco de Aragón, Verduras asadas
# 6               Navarra  Piquillos rellenos de marisco, Ensalada de atún
#
#                                     Vino Tinto  \
# 2    Embutidos, Cordero asado, Paella de carne
# 3             Cochinillo asado, Queso manchego
# 4              Jamón ibérico, Chuletón de vaca
# 5  Ternera a la brasa, Bacalao al ajo aragonés
# 6             Cordero al chilindrón, Chistorra
#
#                                     Vino Rosado  \
# 2  Paella de marisco, Tartar de atún, Brochetas
# 3         Pimientos rellenos, Gazpacho manchego
# 4           Ensalada de frutas, Tarta de frutas
# ...

# %%
maridajes.to_csv("Maridajes por región.csv",index=False)

# %%
pd.read_csv("Maridajes por región.csv")
# Out:
#                             Region  \
# 0             Comunidad Valenciana
# 1               Castilla-La Mancha
# 2                 Variado (España)
# 3                           Aragón
# 4                          Navarra
# 5                         Cataluña
# 6                 Región de Murcia
# 7                         La Rioja
# 8                  Castilla y León
# 9                          Galicia
# 10                       Andalucía
# 11                     Extremadura
# 12        Región Lisboa (Portugal)
# 13      Región Alentejo (Portugal)
# 14         Región Norte (Portugal)
# 15        Región Centro (Portugal)
# 16              Variado (Portugal)
# 17       Región Algarve (Portugal)
# 18                Sicilia (Italia)
# 19                Abruzos (Italia)
# 20                 Apulia (Italia)
# 21               Burdeos (Francia)
# 22                         Francia
# 23  Languedoc-Roussillon (Francia)
# 24              Provenza (Francia)
# ...
